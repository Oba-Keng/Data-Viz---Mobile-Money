# %%
training = pd.read_csv("training.csv");
newTraining = training.head(5)
newTraining
# Out:
#      ID  Q1  Q2  Q3  Q4  Q5  Q6  Q7  Q8_1  Q8_2  ...  Q17  Q18  Q19  Latitude  \
# 0  5086  98   2   3   1   1   2   2     0     0  ...   -1    4    4 -4.460442
# 1  1258  40   1   1   3   5   1   1     1     0  ...    4    1    4 -6.176438
# 2   331  18   2   4   6   3   2   1     0     0  ...   -1    1    1 -6.825702
# 3  6729  50   1   1   3   1   1   1     0     0  ...   -1    1    4 -3.372049
# 4  8671  34   1   1   1   1   2   1     0     1  ...   -1    1    4 -7.179645
#
#    Longitude  mobile_money  savings  borrowing  insurance  \
# 0  29.811396             0        0          0          0
# 1  39.244871             1        1          1          0
# 2  37.652798             1        0          0          0
# 3  35.808307             1        0          1          0
# 4  31.039095             1        1          0          1
#
#    mobile_money_classification
# 0                            0
# 1                            3
# 2                            2
# ...

# %%
import pandas as pd
from matplotlib import pyplot as plt
newTraining.columns
# Out:
# Index(['ID', 'Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6', 'Q7', 'Q8_1', 'Q8_2', 'Q8_3',
#        'Q8_4', 'Q8_5', 'Q8_6', 'Q8_7', 'Q8_8', 'Q8_9', 'Q8_10', 'Q8_11', 'Q9',
#        'Q10', 'Q11', 'Q12', 'Q13', 'Q14', 'Q15', 'Q16', 'Q17', 'Q18', 'Q19',
#        'Latitude', 'Longitude', 'mobile_money', 'savings', 'borrowing',
#        'insurance', 'mobile_money_classification'],
#       dtype='object')

# %%
plt.show(newTraining.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 37 columns):
# ID                             5 non-null int64
# Q1                             5 non-null int64
# Q2                             5 non-null int64
# Q3                             5 non-null int64
# Q4                             5 non-null int64
# Q5                             5 non-null int64
# Q6                             5 non-null int64
# Q7                             5 non-null int64
# Q8_1                           5 non-null int64
# Q8_2                           5 non-null int64
# Q8_3                           5 non-null int64
# Q8_4                           5 non-null int64
# Q8_5                           5 non-null int64
# Q8_6                           5 non-null int64
# Q8_7                           5 non-null int64
# Q8_8                           5 non-null int64
# Q8_9                           5 non-null int64
# ...

# %%
newTraining.isnull()
# Out:
#       ID     Q1     Q2     Q3     Q4     Q5     Q6     Q7   Q8_1   Q8_2  ...  \
# 0  False  False  False  False  False  False  False  False  False  False  ...
# 1  False  False  False  False  False  False  False  False  False  False  ...
# 2  False  False  False  False  False  False  False  False  False  False  ...
# 3  False  False  False  False  False  False  False  False  False  False  ...
# 4  False  False  False  False  False  False  False  False  False  False  ...
#
#      Q17    Q18    Q19  Latitude  Longitude  mobile_money  savings  borrowing  \
# 0  False  False  False     False      False         False    False      False
# 1  False  False  False     False      False         False    False      False
# 2  False  False  False     False      False         False    False      False
# 3  False  False  False     False      False         False    False      False
# 4  False  False  False     False      False         False    False      False
#
# ...

# %%
newTraining.isnull().sum()
# Out:
# ID                             0
# Q1                             0
# Q2                             0
# Q3                             0
# Q4                             0
# Q5                             0
# Q6                             0
# Q7                             0
# Q8_1                           0
# Q8_2                           0
# Q8_3                           0
# Q8_4                           0
# Q8_5                           0
# Q8_6                           0
# Q8_7                           0
# Q8_8                           0
# Q8_9                           0
# Q8_10                          0
# Q8_11                          0
# Q9                             0
# Q10                            0
# Q11                            0
# Q12                            0
# Q13                            0
# Q14                            0
# Q15                            0
# Q16                            0
# Q17                            0
# ...

# %% [markdown]
# There are no missing observations in the data set,all the values are valid

# %%
import scipy
from scipy import stats

# %%
newTraining.sum(axis=1)
# Out:
# 0    5228.350954
# 1    1373.068432
# 2     402.827096
# 3    6834.436258
# 4    8749.859450
# dtype: float64

# %% [markdown]
# The sum of all values in all the rows

# %%
newTraining.sum()
# Out:
# ID                             22075.000000
# Q1                               240.000000
# Q2                                 7.000000
# Q3                                10.000000
# Q4                                14.000000
# Q5                                11.000000
# Q6                                 8.000000
# Q7                                 6.000000
# Q8_1                               1.000000
# Q8_2                               1.000000
# Q8_3                               0.000000
# Q8_4                               1.000000
# Q8_5                               0.000000
# Q8_6                               0.000000
# Q8_7                               0.000000
# Q8_8                               0.000000
# Q8_9                               2.000000
# Q8_10                              0.000000
# Q8_11                              0.000000
# Q9                                -3.000000
# Q10                               -3.000000
# ...

# %% [markdown]
# total of each value inside each column

# %%
newTraining.median()
# Out:
# ID                             5086.000000
# Q1                               40.000000
# Q2                                1.000000
# Q3                                1.000000
# Q4                                3.000000
# Q5                                1.000000
# Q6                                2.000000
# Q7                                1.000000
# Q8_1                              0.000000
# Q8_2                              0.000000
# Q8_3                              0.000000
# Q8_4                              0.000000
# Q8_5                              0.000000
# Q8_6                              0.000000
# Q8_7                              0.000000
# Q8_8                              0.000000
# Q8_9                              0.000000
# Q8_10                             0.000000
# Q8_11                             0.000000
# Q9                               -1.000000
# Q10                              -1.000000
# Q11                              -1.000000
# ...

# %% [markdown]
# This is the middle value for each column in the data set

# %% [markdown]
# The average for values in each column

# %%
newTraining.mean()
# Out:
# ID                             4415.000000
# Q1                               48.000000
# Q2                                1.400000
# Q3                                2.000000
# Q4                                2.800000
# Q5                                2.200000
# Q6                                1.600000
# Q7                                1.200000
# Q8_1                              0.200000
# Q8_2                              0.200000
# Q8_3                              0.000000
# Q8_4                              0.200000
# Q8_5                              0.000000
# Q8_6                              0.000000
# Q8_7                              0.000000
# Q8_8                              0.000000
# Q8_9                              0.400000
# Q8_10                             0.000000
# Q8_11                             0.000000
# Q9                               -0.600000
# Q10                              -0.600000
# Q11                              -1.000000
# ...

# %%
newTraining.max()
# Out:
# ID                             8671.000000
# Q1                               98.000000
# Q2                                2.000000
# Q3                                4.000000
# Q4                                6.000000
# Q5                                5.000000
# Q6                                2.000000
# Q7                                2.000000
# Q8_1                              1.000000
# Q8_2                              1.000000
# Q8_3                              0.000000
# Q8_4                              1.000000
# Q8_5                              0.000000
# Q8_6                              0.000000
# Q8_7                              0.000000
# Q8_8                              0.000000
# Q8_9                              1.000000
# Q8_10                             0.000000
# Q8_11                             0.000000
# Q9                                1.000000
# Q10                               1.000000
# Q11                              -1.000000
# ...

# %% [markdown]
# The max value for each variable in each column

# %%
ID = newTraining.ID
ID.idxmax()
# Out:
# 4

# %% [markdown]
# index of the variable  where the max number was found

# %%
newTraining.std()
# Out:
# ID                             3555.421142
# Q1                               30.265492
# Q2                                0.547723
# Q3                                1.414214
# Q4                                2.049390
# Q5                                1.788854
# Q6                                0.547723
# Q7                                0.447214
# Q8_1                              0.447214
# Q8_2                              0.447214
# Q8_3                              0.000000
# Q8_4                              0.447214
# Q8_5                              0.000000
# Q8_6                              0.000000
# Q8_7                              0.000000
# Q8_8                              0.000000
# Q8_9                              0.547723
# Q8_10                             0.000000
# Q8_11                             0.000000
# Q9                                0.894427
# Q10                               0.894427
# Q11                               0.000000
# ...

# %% [markdown]
# standard deviation for each variable in the dataframe

# %%
newTraining.var()
# Out:
# ID                             1.264102e+07
# Q1                             9.160000e+02
# Q2                             3.000000e-01
# Q3                             2.000000e+00
# Q4                             4.200000e+00
# Q5                             3.200000e+00
# Q6                             3.000000e-01
# Q7                             2.000000e-01
# Q8_1                           2.000000e-01
# Q8_2                           2.000000e-01
# Q8_3                           0.000000e+00
# Q8_4                           2.000000e-01
# Q8_5                           0.000000e+00
# Q8_6                           0.000000e+00
# Q8_7                           0.000000e+00
# Q8_8                           0.000000e+00
# Q8_9                           3.000000e-01
# Q8_10                          0.000000e+00
# Q8_11                          0.000000e+00
# Q9                             8.000000e-01
# Q10                            8.000000e-01
# ...

# %% [markdown]
# variance for each column in the dataframe

# %%
Q1 = newTraining.Q1
Q1.value_counts()
# Out:
# 34    1
# 18    1
# 98    1
# 50    1
# 40    1
# Name: Q1, dtype: int64

# %% [markdown]
# The number of unique values within each variable

# %%
newTraining.describe()
# Out:
#                 ID         Q1        Q2        Q3       Q4        Q5  \
# count     5.000000   5.000000  5.000000  5.000000  5.00000  5.000000
# mean   4415.000000  48.000000  1.400000  2.000000  2.80000  2.200000
# std    3555.421142  30.265492  0.547723  1.414214  2.04939  1.788854
# min     331.000000  18.000000  1.000000  1.000000  1.00000  1.000000
# 25%    1258.000000  34.000000  1.000000  1.000000  1.00000  1.000000
# 50%    5086.000000  40.000000  1.000000  1.000000  3.00000  1.000000
# 75%    6729.000000  50.000000  2.000000  3.000000  3.00000  3.000000
# max    8671.000000  98.000000  2.000000  4.000000  6.00000  5.000000
#
#              Q6        Q7      Q8_1      Q8_2  ...       Q17       Q18  \
# count  5.000000  5.000000  5.000000  5.000000  ...  5.000000  5.000000
# mean   1.600000  1.200000  0.200000  0.200000  ...  0.000000  1.600000
# std    0.547723  0.447214  0.447214  0.447214  ...  2.236068  1.341641
# ...

# %% [markdown]
# a full statistical description of each variable

# %%
import seaborn as sns
import numpy as np

# %%
sns.relplot(x="Q1",y="mobile_money", hue = 'mobile_money_classification',data=newTraining)
sns.relplot(x="Q1",y="savings",hue = 'mobile_money_classification',data=newTraining)
sns.relplot(x="Q1",y="borrowing",hue = 'mobile_money_classification',data=newTraining)
sns.relplot(x="Q1",y="insurance",hue = 'mobile_money_classification',data=newTraining)

# %%
sns.relplot(x="Q2",y="mobile_money",hue = 'mobile_money_classification',data=newTraining)
sns.relplot(x="Q2",y="savings",hue = 'mobile_money_classification',data=newTraining)
sns.relplot(x="Q2",y="borrowing",hue = 'mobile_money_classification',data=newTraining)
sns.relplot(x="Q2",y="insurance",hue = 'mobile_money_classification',data=newTraining)

# %%
sns.relplot(x="Q3",y="mobile_money", hue = 'mobile_money_classification',data=newTraining)
sns.relplot(x="Q3",y="savings", hue = 'mobile_money_classification',data=newTraining)
sns.relplot(x="Q3",y="borrowing",hue = 'mobile_money_classification',data=newTraining)
sns.relplot(x="Q3",y="insurance",hue = 'mobile_money_classification',data=newTraining)

# %%
sns.relplot(x="Q6",y="mobile_money", hue = 'mobile_money_classification',data=newTraining)
sns.relplot(x="Q6",y="savings",hue = 'mobile_money_classification',data=newTraining)
sns.relplot(x="Q6",y="borrowing",hue = 'mobile_money_classification',data=newTraining)
sns.relplot(x="Q6",y="insurance",hue = 'mobile_money_classification',data=newTraining)

# %%
sns.relplot(x="Q1",y="mobile_money", hue = 'mobile_money_classification',data=newTraining,kind="line")
sns.relplot(x="Q1",y="savings",hue = 'mobile_money_classification',data=newTraining,kind="line")
sns.relplot(x="Q1",y="borrowing",hue = 'mobile_money_classification',data=newTraining,kind="line")
sns.relplot(x="Q1",y="insurance",hue = 'mobile_money_classification',data=newTraining,kind="line")

# %%
sns.relplot(x="Q2",y="mobile_money", hue = 'mobile_money_classification',data=newTraining,kind="line")
sns.relplot(x="Q2",y="savings",hue = 'mobile_money_classification',data=newTraining,kind="line")
sns.relplot(x="Q2",y="borrowing",hue = 'mobile_money_classification',data=newTraining,kind="line")
sns.relplot(x="Q2",y="insurance",hue = 'mobile_money_classification',data=newTraining,kind="line")

# %%
sns.relplot(x="Q3",y="mobile_money", hue = 'mobile_money_classification',data=newTraining,kind="line")
sns.relplot(x="Q3",y="savings",hue = 'mobile_money_classification',data=newTraining,kind="line")
sns.relplot(x="Q3",y="borrowing",hue = 'mobile_money_classification',data=newTraining,kind="line")
sns.relplot(x="Q3",y="insurance",hue = 'mobile_money_classification',data=newTraining,kind="line")

# %%
sns.relplot(x="Q6",y="mobile_money", hue = 'mobile_money_classification',data=newTraining,kind="line")
sns.relplot(x="Q6",y="savings", hue = 'mobile_money_classification',data=newTraining,kind="line")
sns.relplot(x="Q6",y="borrowing",hue = 'mobile_money_classification',data=newTraining,kind="line")
sns.relplot(x="Q6",y="insurance",hue = 'mobile_money_classification',data=newTraining,kind="line")

# %%
sns.relplot(x="Q8_1",y="mobile_money", hue = 'mobile_money_classification',data=newTraining,kind="line")
sns.relplot(x="Q8_1",y="savings", hue = 'mobile_money_classification',data=newTraining,kind="line")
sns.relplot(x="Q8_1",y="borrowing",hue = 'mobile_money_classification',data=newTraining,kind="line")
sns.relplot(x="Q8_1",y="insurance",hue = 'mobile_money_classification',data=newTraining,kind="line")

# %%
sns.relplot(x="Q8_2",y="mobile_money", hue = 'mobile_money_classification',data=newTraining,kind="line")
sns.relplot(x="Q8_2",y="savings", hue = 'mobile_money_classification',data=newTraining,kind="line")
sns.relplot(x="Q8_2",y="borrowing",hue = 'mobile_money_classification',data=newTraining,kind="line")
sns.relplot(x="Q8_2",y="insurance",hue = 'mobile_money_classification',data=newTraining,kind="line")

# %%
sns.relplot(x="Q8_3",y="mobile_money", hue = 'mobile_money_classification',data=newTraining,kind="line")
sns.relplot(x="Q8_3",y="savings", hue = 'mobile_money_classification',data=newTraining,kind="line")
sns.relplot(x="Q8_3",y="borrowing",hue = 'mobile_money_classification',data=newTraining,kind="line")
sns.relplot(x="Q8_3",y="insurance",hue = 'mobile_money_classification',data=newTraining,kind="line")

# %%
sns.relplot(x="Q8_4",y="mobile_money", hue = 'mobile_money_classification',data=newTraining,kind="line")
sns.relplot(x="Q8_4",y="savings", hue = 'mobile_money_classification',data=newTraining,kind="line")
sns.relplot(x="Q8_4",y="borrowing",hue = 'mobile_money_classification',data=newTraining,kind="line")
sns.relplot(x="Q8_4",y="insurance",hue = 'mobile_money_classification',data=newTraining,kind="line")

# %%
sns.relplot(x="Q8_5",y="mobile_money", hue = 'mobile_money_classification',data=newTraining,kind="line")
sns.relplot(x="Q8_5",y="savings", hue = 'mobile_money_classification',data=newTraining,kind="line")
sns.relplot(x="Q8_5",y="borrowing",hue = 'mobile_money_classification',data=newTraining,kind="line")
sns.relplot(x="Q8_5",y="insurance",hue = 'mobile_money_classification',data=newTraining,kind="line")

# %%
sns.relplot(x="Q8_6",y="mobile_money", hue = 'mobile_money_classification',data=newTraining,kind="line")
sns.relplot(x="Q8_6",y="savings", hue = 'mobile_money_classification',data=newTraining,kind="line")
sns.relplot(x="Q8_6",y="borrowing",hue = 'mobile_money_classification',data=newTraining,kind="line")
sns.relplot(x="Q8_6",y="insurance",hue = 'mobile_money_classification',data=newTraining,kind="line")

# %%
sns.relplot(x="Q8_7",y="mobile_money", hue = 'mobile_money_classification',data=newTraining,kind="line")
sns.relplot(x="Q8_7",y="savings", hue = 'mobile_money_classification',data=newTraining,kind="line")
sns.relplot(x="Q8_7",y="borrowing",hue = 'mobile_money_classification',data=newTraining,kind="line")
sns.relplot(x="Q8_7",y="insurance",hue = 'mobile_money_classification',data=newTraining,kind="line")

# %%
sns.relplot(x="Q8_8",y="mobile_money", hue = 'mobile_money_classification',data=newTraining,kind="line")
sns.relplot(x="Q8_8",y="savings", hue = 'mobile_money_classification',data=newTraining,kind="line")
sns.relplot(x="Q8_8",y="borrowing",hue = 'mobile_money_classification',data=newTraining,kind="line")
sns.relplot(x="Q8_8",y="insurance",hue = 'mobile_money_classification',data=newTraining,kind="line")

# %%
sns.relplot(x="Q8_9",y="mobile_money", hue = 'mobile_money_classification',data=newTraining,kind="line",x="Q8_9",y="savings", hue = 'mobile_money_classification',data=newTraining,kind="line")
# sns.relplot(x="Q8_9",y="savings", hue = 'mobile_money_classification',data=newTraining,kind="line")
sns.relplot(x="Q8_9",y="borrowing",hue = 'mobile_money_classification',data=newTraining,kind="line")
sns.relplot(x="Q8_9",y="insurance",hue = 'mobile_money_classification',data=newTraining,kind="line")
# Out:
#   File "<ipython-input-66-4d59e88a1faa>", line 1
#     sns.relplot(x="Q8_9",y="mobile_money", hue = 'mobile_money_classification',data=newTraining,kind="line",x="Q8_9",y="savings", hue = 'mobile_money_classification',data=newTraining,kind="line")
#                                                                                                            ^
# SyntaxError: keyword argument repeated

# %%
sns.catplot(x="Q2",y="mobile_money", hue = 'mobile_money_classification',data=newTraining,kind="box")
sns.catplot(x="Q2",y="savings",hue = 'mobile_money_classification',data=newTraining,kind="box")
sns.catplot(x="Q2",y="borrowing",hue = 'mobile_money_classification',data=newTraining,kind="box")
sns.catplot(x="Q2",y="insurance",hue = 'mobile_money_classification',data=newTraining,kind="box")

# %%
sns.catplot(x="Q3",y="mobile_money", hue = 'mobile_money_classification',data=newTraining,kind="box")
sns.catplot(x="Q3",y="savings",hue = 'mobile_money_classification',data=newTraining,kind="box")
sns.catplot(x="Q3",y="borrowing",hue = 'mobile_money_classification',data=newTraining,kind="box")
sns.catplot(x="Q3",y="insurance",hue = 'mobile_money_classification',data=newTraining,kind="box")

# %%
sns.catplot(x="Q6",y="mobile_money", hue = 'mobile_money_classification',data=newTraining,kind="box")
sns.catplot(x="Q6",y="savings",hue = 'mobile_money_classification',data=newTraining,kind="box")
sns.catplot(x="Q6",y="borrowing",hue = 'mobile_money_classification',data=newTraining,kind="box")
sns.catplot(x="Q6",y="insurance",hue = 'mobile_money_classification',data=newTraining,kind="box")

# %%
sns.catplot(x="Q8_1",y="mobile_money", hue = 'mobile_money_classification',data=newTraining,kind="box")
sns.catplot(x="Q8_1",y="savings",hue = 'mobile_money_classification',data=newTraining,kind="box")
sns.catplot(x="Q8_1",y="borrowing",hue = 'mobile_money_classification',data=newTraining,kind="box")
sns.catplot(x="Q8_1",y="insurance",hue = 'mobile_money_classification',data=newTraining,kind="box")

# %%
sns.catplot(x="Q8_2",y="mobile_money", hue = 'mobile_money_classification',data=newTraining,kind="box")
sns.catplot(x="Q8_2",y="savings",hue = 'mobile_money_classification',data=newTraining,kind="box")
sns.catplot(x="Q8_2",y="borrowing",hue = 'mobile_money_classification',data=newTraining,kind="box")
sns.catplot(x="Q8_2",y="insurance",hue = 'mobile_money_classification',data=newTraining,kind="box")

# %%
sns.catplot(x="Q8_3",y="mobile_money", hue = 'mobile_money_classification',data=newTraining,kind="box")
sns.catplot(x="Q8_3",y="savings",hue = 'mobile_money_classification',data=newTraining,kind="box")
sns.catplot(x="Q8_3",y="borrowing",hue = 'mobile_money_classification',data=newTraining,kind="box")
sns.catplot(x="Q8_3",y="insurance",hue = 'mobile_money_classification',data=newTraining,kind="box")

# %%
sns.catplot(x="Q8_4",y="mobile_money", hue = 'mobile_money_classification',data=newTraining,kind="box")
sns.catplot(x="Q8_4",y="savings",hue = 'mobile_money_classification',data=newTraining,kind="box")
sns.catplot(x="Q8_4",y="borrowing",hue = 'mobile_money_classification',data=newTraining,kind="box")
sns.catplot(x="Q8_4",y="insurance",hue = 'mobile_money_classification',data=newTraining,kind="box")

# %%
sns.catplot(x="Q8_5",y="mobile_money", hue = 'mobile_money_classification',data=newTraining,kind="box")
sns.catplot(x="Q8_5",y="savings",hue = 'mobile_money_classification',data=newTraining,kind="box")
sns.catplot(x="Q8_5",y="borrowing",hue = 'mobile_money_classification',data=newTraining,kind="box")
sns.catplot(x="Q8_5",y="insurance",hue = 'mobile_money_classification',data=newTraining,kind="box")

# %%
sns.catplot(x="Q8_6",y="mobile_money", hue = 'mobile_money_classification',data=newTraining,kind="box")
sns.catplot(x="Q8_6",y="savings",hue = 'mobile_money_classification',data=newTraining,kind="box")
sns.catplot(x="Q8_6",y="borrowing",hue = 'mobile_money_classification',data=newTraining,kind="box")
sns.catplot(x="Q8_6",y="insurance",hue = 'mobile_money_classification',data=newTraining,kind="box")

# %%
sns.catplot(x="Q8_7",y="mobile_money", hue = 'mobile_money_classification',data=newTraining,kind="box")
sns.catplot(x="Q8_7",y="savings",hue = 'mobile_money_classification',data=newTraining,kind="box")
sns.catplot(x="Q8_7",y="borrowing",hue = 'mobile_money_classification',data=newTraining,kind="box")
sns.catplot(x="Q8_7",y="insurance",hue = 'mobile_money_classification',data=newTraining,kind="box")

# %%
sns.catplot(x="Q8_8",y="mobile_money", hue = 'mobile_money_classification',data=newTraining,kind="box")
sns.catplot(x="Q8_8",y="savings",hue = 'mobile_money_classification',data=newTraining,kind="box")
sns.catplot(x="Q8_8",y="borrowing",hue = 'mobile_money_classification',data=newTraining,kind="box")
sns.catplot(x="Q8_8",y="insurance",hue = 'mobile_money_classification',data=newTraining,kind="box")

# %%
sns.catplot(x="Q8_9",y="mobile_money", hue = 'mobile_money_classification',data=newTraining,kind="box")
sns.catplot(x="Q8_9",y="savings",hue = 'mobile_money_classification',data=newTraining,kind="box")
sns.catplot(x="Q8_9",y="borrowing",hue = 'mobile_money_classification',data=newTraining,kind="box")
sns.catplot(x="Q8_9",y="insurance",hue = 'mobile_money_classification',data=newTraining,kind="box")

# %%
from scipy import stats
newTraining=np.random.normal(loc=5,size=100,scale=2)
sns.distplot(newTraining)

# %%
newTraining
training_plot = sns.FacetGrid(newTraining,col="mobile_money")
training_plot.map(plt.hist,"Q1")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-83-1d5b52c6ae6e> in <module>
#       1 newTraining
# ----> 2 training_plot = sns.FacetGrid(newTraining,col="mobile_money")
#       3 training_plot.map(plt.hist,"Q1")
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py in __init__(self, data, row, col, hue, col_wrap, sharex, sharey, height, aspect, palette, row_order, col_order, hue_order, hue_kws, dropna, legend_out, despine, margin_titles, xlim, ylim, subplot_kws, gridspec_kws, size)
#     248             col_names = []
#     249         else:
# --> 250             col_names = utils.categorical_order(data[col], col_order)
#     251
#     252         # Additional dict of kwarg -> list of values for mapping the hue var
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
training_plot = sns.FacetGrid(newTraining,col="mobile_money")
training_plot.map(plt.hist,"Q2")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-82-62522eee3a2c> in <module>
# ----> 1 training_plot = sns.FacetGrid(newTraining,col="mobile_money")
#       2 training_plot.map(plt.hist,"Q2")
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py in __init__(self, data, row, col, hue, col_wrap, sharex, sharey, height, aspect, palette, row_order, col_order, hue_order, hue_kws, dropna, legend_out, despine, margin_titles, xlim, ylim, subplot_kws, gridspec_kws, size)
#     248             col_names = []
#     249         else:
# --> 250             col_names = utils.categorical_order(data[col], col_order)
#     251
#     252         # Additional dict of kwarg -> list of values for mapping the hue var
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
training_plot = sns.FacetGrid(training,col="mobile_money")
training_plot.map(plt.hist,"Q3")

# %% [markdown]
# The following graphs(scatter,line,box) are used to visually represent the relationship between financial services accessed (non, momible, both) and age, gender, marital status, land ownership and type of income.
