# %%
import pandas as pd
from matplotlib import pyplot as plt
training = pd.read_csv("training.csv");
training
# Out:
#         ID  Q1  Q2  Q3  Q4  Q5  Q6  Q7  Q8_1  Q8_2  ...  Q17  Q18  Q19  \
# 0     5086  98   2   3   1   1   2   2     0     0  ...   -1    4    4
# 1     1258  40   1   1   3   5   1   1     1     0  ...    4    1    4
# 2      331  18   2   4   6   3   2   1     0     0  ...   -1    1    1
# 3     6729  50   1   1   3   1   1   1     0     0  ...   -1    1    4
# 4     8671  34   1   1   1   1   2   1     0     1  ...   -1    1    4
# 5     5462  35   1   1   3   3   2   1     0     1  ...   -1    1    1
# 6     4886  31   2   1   3   1   2   1     0     1  ...   -1    1    2
# 7      621  23   2   4   5   5   2   1     0     0  ...    1    2    2
# 8     8302  56   2   3   3   3   2   2     0     1  ...   -1    1    1
# 9     4704  37   2   1   3   3   2   1     0     1  ...   -1    1    4
# 10    2758  18   2   4   5   5   2   1     0     0  ...   -1    1    1
# 11    2536  29   2   1   6   1   2   1     0     0  ...    1    1    4
# ...

# %%
print(training.columns)
# Out:
# Index(['ID', 'Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6', 'Q7', 'Q8_1', 'Q8_2', 'Q8_3',
#        'Q8_4', 'Q8_5', 'Q8_6', 'Q8_7', 'Q8_8', 'Q8_9', 'Q8_10', 'Q8_11', 'Q9',
#        'Q10', 'Q11', 'Q12', 'Q13', 'Q14', 'Q15', 'Q16', 'Q17', 'Q18', 'Q19',
#        'Latitude', 'Longitude', 'mobile_money', 'savings', 'borrowing',
#        'insurance', 'mobile_money_classification'],
#       dtype='object')

# %%
import pandas as pd
from matplotlib import pyplot as plt
training = pd.read_csv("training.csv");
training
print(training.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7094 entries, 0 to 7093
# Data columns (total 37 columns):
# ID                             7094 non-null int64
# Q1                             7094 non-null int64
# Q2                             7094 non-null int64
# Q3                             7094 non-null int64
# Q4                             7094 non-null int64
# Q5                             7094 non-null int64
# Q6                             7094 non-null int64
# Q7                             7094 non-null int64
# Q8_1                           7094 non-null int64
# Q8_2                           7094 non-null int64
# Q8_3                           7094 non-null int64
# Q8_4                           7094 non-null int64
# Q8_5                           7094 non-null int64
# Q8_6                           7094 non-null int64
# Q8_7                           7094 non-null int64
# Q8_8                           7094 non-null int64
# ...

# %%
import pandas as pd
from matplotlib import pyplot as plt
training = pd.read_csv("training.csv");
print(training.isnull());
# Out:
#          ID     Q1     Q2     Q3     Q4     Q5     Q6     Q7   Q8_1   Q8_2  \
# 0     False  False  False  False  False  False  False  False  False  False
# 1     False  False  False  False  False  False  False  False  False  False
# 2     False  False  False  False  False  False  False  False  False  False
# 3     False  False  False  False  False  False  False  False  False  False
# 4     False  False  False  False  False  False  False  False  False  False
# 5     False  False  False  False  False  False  False  False  False  False
# 6     False  False  False  False  False  False  False  False  False  False
# 7     False  False  False  False  False  False  False  False  False  False
# 8     False  False  False  False  False  False  False  False  False  False
# 9     False  False  False  False  False  False  False  False  False  False
# 10    False  False  False  False  False  False  False  False  False  False
# ...

# %%
import pandas as pd
from matplotlib import pyplot as plt
training = pd.read_csv("training.csv");
print(training.isnull().sum())
# Out:
# ID                             0
# Q1                             0
# Q2                             0
# Q3                             0
# Q4                             0
# Q5                             0
# Q6                             0
# Q7                             0
# Q8_1                           0
# Q8_2                           0
# Q8_3                           0
# Q8_4                           0
# Q8_5                           0
# Q8_6                           0
# Q8_7                           0
# Q8_8                           0
# Q8_9                           0
# Q8_10                          0
# Q8_11                          0
# Q9                             0
# Q10                            0
# Q11                            0
# Q12                            0
# Q13                            0
# Q14                            0
# Q15                            0
# Q16                            0
# Q17                            0
# ...

# %% [markdown]
# There are no missing observations in the data set,all the values are valid

# %%
import scipy
from scipy import stats

# %%
training.sum(axis=1)
# Out:
# 0       5228.350954
# 1       1373.068432
# 2        402.827096
# 3       6834.436258
# 4       8749.859450
# 5       5548.775411
# 6       4974.747158
# 7        712.517876
# 8       8425.677704
# 9       4805.735443
# 10      2845.194483
# 11      2622.976090
# 12      8937.989581
# 13      5531.213116
# 14      3630.029437
# 15      6655.561375
# 16      7846.539246
# 17      4321.680896
# 18      7094.416766
# 19      1071.882958
# 20      5659.172691
# 21      2372.316182
# 22      8379.083797
# 23      3127.083573
# 24       991.381826
# 25      1426.918833
# 26      1332.012428
# 27      5128.466563
# 28       726.995151
# 29       904.826467
#            ...
# 7064    6018.154383
# 7065    6127.518937
# 7066    3382.151556
# 7067    7785.751809
# 7068    2554.325607
# 7069    7353.659694
# 7070    4829.622017
# 7071     591.432632
# 7072    1371.235929
# 7073    5591.528891
# 7074    9173.397484
# 7075    9523.707592
# 7076    7696.218207
# 7077    5151.636548
# ...

# %% [markdown]
# The sum of all values in all the rows

# %%
training.sum()
# Out:
# ID                             3.364420e+07
# Q1                             2.712710e+05
# Q2                             1.106600e+04
# Q3                             1.268000e+04
# Q4                             2.170800e+04
# Q5                             1.808200e+04
# Q6                             1.305700e+04
# Q7                             9.917000e+03
# Q8_1                           4.410000e+02
# Q8_2                           4.470000e+03
# Q8_3                           4.120000e+02
# Q8_4                           2.393000e+03
# Q8_5                           6.700000e+01
# Q8_6                           3.400000e+01
# Q8_7                           3.400000e+01
# Q8_8                           1.310000e+02
# Q8_9                           1.112000e+03
# Q8_10                          4.100000e+02
# Q8_11                          9.000000e+00
# Q9                            -5.637000e+03
# Q10                            6.215000e+03
# ...

# %% [markdown]
# total of each value inside each column

# %%
training.median()
# Out:
# ID                             4744.500000
# Q1                               35.000000
# Q2                                2.000000
# Q3                                1.000000
# Q4                                3.000000
# Q5                                3.000000
# Q6                                2.000000
# Q7                                1.000000
# Q8_1                              0.000000
# Q8_2                              1.000000
# Q8_3                              0.000000
# Q8_4                              0.000000
# Q8_5                              0.000000
# Q8_6                              0.000000
# Q8_7                              0.000000
# Q8_8                              0.000000
# Q8_9                              0.000000
# Q8_10                             0.000000
# Q8_11                             0.000000
# Q9                               -1.000000
# Q10                               1.000000
# Q11                              -1.000000
# ...

# %% [markdown]
# This is the middle value for each column in the data set

# %% [markdown]
# The average for values in each column

# %%
training.mean()
# Out:
# ID                             4742.627291
# Q1                               38.239498
# Q2                                1.559910
# Q3                                1.787426
# Q4                                3.060051
# Q5                                2.548915
# Q6                                1.840569
# Q7                                1.397942
# Q8_1                              0.062165
# Q8_2                              0.630110
# Q8_3                              0.058077
# Q8_4                              0.337327
# Q8_5                              0.009445
# Q8_6                              0.004793
# Q8_7                              0.004793
# Q8_8                              0.018466
# Q8_9                              0.156752
# Q8_10                             0.057795
# Q8_11                             0.001269
# Q9                               -0.794615
# Q10                               0.876092
# Q11                              -0.692134
# ...

# %%
print(training.max())
# Out:
# ID                             9459.000000
# Q1                              100.000000
# Q2                                2.000000
# Q3                                4.000000
# Q4                                8.000000
# Q5                                6.000000
# Q6                                2.000000
# Q7                                2.000000
# Q8_1                              1.000000
# Q8_2                              1.000000
# Q8_3                              1.000000
# Q8_4                              1.000000
# Q8_5                              1.000000
# Q8_6                              1.000000
# Q8_7                              1.000000
# Q8_8                              1.000000
# Q8_9                              1.000000
# Q8_10                             1.000000
# Q8_11                             1.000000
# Q9                                7.000000
# Q10                              10.000000
# Q11                              12.000000
# ...

# %% [markdown]
# The max value for each variable in each column

# %%
ID = training.ID
ID.idxmax()
# Out:
# 3214

# %% [markdown]
# index of the variable  where the max number was found

# %%
training.std()
# Out:
# ID                             2731.120086
# Q1                               16.332148
# Q2                                0.496433
# Q3                                1.165160
# Q4                                1.557779
# Q5                                1.534257
# Q6                                0.366103
# Q7                                0.489508
# Q8_1                              0.241472
# Q8_2                              0.482809
# Q8_3                              0.233906
# Q8_4                              0.472831
# Q8_5                              0.096730
# Q8_6                              0.069069
# Q8_7                              0.069069
# Q8_8                              0.134640
# Q8_9                              0.363593
# Q8_10                             0.233372
# Q8_11                             0.035598
# Q9                                0.895007
# Q10                               2.172787
# Q11                               1.411600
# ...

# %% [markdown]
# standard deviation for each variable in the dataframe

# %%
training.var()
# Out:
# ID                             7.459017e+06
# Q1                             2.667391e+02
# Q2                             2.464456e-01
# Q3                             1.357597e+00
# Q4                             2.426677e+00
# Q5                             2.353944e+00
# Q6                             1.340313e-01
# Q7                             2.396179e-01
# Q8_1                           5.830892e-02
# Q8_2                           2.331043e-01
# Q8_3                           5.471199e-02
# Q8_4                           2.235691e-01
# Q8_5                           9.356720e-03
# Q8_6                           4.770484e-03
# Q8_7                           4.770484e-03
# Q8_8                           1.812786e-02
# Q8_9                           1.321996e-01
# Q8_10                          5.446270e-02
# Q8_11                          1.267247e-03
# Q9                             8.010368e-01
# Q10                            4.721005e+00
# ...

# %% [markdown]
# variance for each column in the dataframe

# %%
Q1 = training.Q1
Q1.value_counts()
# Out:
# 30     312
# 25     260
# 35     247
# 40     232
# 32     229
# 22     226
# 28     224
# 23     216
# 20     200
# 27     197
# 26     189
# 24     187
# 45     187
# 29     176
# 34     160
# 18     158
# 21     151
# 38     142
# 36     142
# 19     140
# 50     139
# 17     138
# 42     134
# 31     128
# 33     127
# 37     125
# 16     119
# 43     117
# 60     114
# 47     104
#       ...
# 72      31
# 67      26
# 78      23
# 69      22
# 76      21
# 73      19
# 82      18
# 74      17
# 71      17
# 77      15
# 85      14
# 90      12
# 79      12
# 81       8
# 88       7
# 83       6
# 100      5
# 86       5
# 84       3
# 87       3
# 98       3
# 91       2
# 94       2
# 95       2
# 99       1
# 92       1
# 96       1
# 89       1
# 93       1
# 97       1
# Name: Q1, Length: 85, dtype: int64

# %% [markdown]
# The number of unique values within each variable

# %%
training.describe()
# Out:
#                 ID           Q1           Q2           Q3           Q4  \
# count  7094.000000  7094.000000  7094.000000  7094.000000  7094.000000
# mean   4742.627291    38.239498     1.559910     1.787426     3.060051
# std    2731.120086    16.332148     0.496433     1.165160     1.557779
# min       1.000000    16.000000     1.000000     1.000000     1.000000
# 25%    2397.250000    25.000000     1.000000     1.000000     2.000000
# 50%    4744.500000    35.000000     2.000000     1.000000     3.000000
# 75%    7105.000000    48.000000     2.000000     3.000000     3.000000
# max    9459.000000   100.000000     2.000000     4.000000     8.000000
#
#                 Q5           Q6           Q7         Q8_1         Q8_2  ...  \
# count  7094.000000  7094.000000  7094.000000  7094.000000  7094.000000  ...
# mean      2.548915     1.840569     1.397942     0.062165     0.630110  ...
# std       1.534257     0.366103     0.489508     0.241472     0.482809  ...
# ...

# %% [markdown]
# a full statistical description of each variable

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
training = pd.read_csv("training.csv");
sns.relplot(x="Q1",y="mobile_money", hue = 'mobile_money_classification',data=training)
sns.relplot(x="Q1",y="savings",hue = 'mobile_money_classification',data=training)
sns.relplot(x="Q1",y="borrowing",hue = 'mobile_money_classification',data=training)
sns.relplot(x="Q1",y="insurance",hue = 'mobile_money_classification',data=training)

# %%
sns.relplot(x="Q2",y="mobile_money",hue = 'mobile_money_classification',data=training)
sns.relplot(x="Q2",y="savings",hue = 'mobile_money_classification',data=training)
sns.relplot(x="Q2",y="borrowing",hue = 'mobile_money_classification',data=training)
sns.relplot(x="Q2",y="insurance",hue = 'mobile_money_classification',data=training)

# %%
sns.relplot(x="Q3",y="mobile_money", hue = 'mobile_money_classification',data=training)
sns.relplot(x="Q3",y="savings", hue = 'mobile_money_classification',data=training)
sns.relplot(x="Q3",y="borrowing",hue = 'mobile_money_classification',data=training)
sns.relplot(x="Q3",y="insurance",hue = 'mobile_money_classification',data=training)

# %%
sns.relplot(x="Q6",y="mobile_money", hue = 'mobile_money_classification',data=training)
sns.relplot(x="Q6",y="savings",hue = 'mobile_money_classification',data=training)
sns.relplot(x="Q6",y="borrowing",hue = 'mobile_money_classification',data=training)
sns.relplot(x="Q6",y="insurance",hue = 'mobile_money_classification',data=training)

# %%
sns.relplot(x="Q1",y="mobile_money", hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q1",y="savings",hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q1",y="borrowing",hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q1",y="insurance",hue = 'mobile_money_classification',data=training,kind="line")

# %%
sns.relplot(x="Q2",y="mobile_money", hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q2",y="savings",hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q2",y="borrowing",hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q2",y="insurance",hue = 'mobile_money_classification',data=training,kind="line")

# %%
sns.relplot(x="Q3",y="mobile_money", hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q3",y="savings",hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q3",y="borrowing",hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q3",y="insurance",hue = 'mobile_money_classification',data=training,kind="line")

# %%
sns.relplot(x="Q6",y="mobile_money", hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q6",y="savings", hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q6",y="borrowing",hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q6",y="insurance",hue = 'mobile_money_classification',data=training,kind="line")

# %%
sns.relplot(x="Q8_1",y="mobile_money", hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q8_1",y="savings", hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q8_1",y="borrowing",hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q8_1",y="insurance",hue = 'mobile_money_classification',data=training,kind="line")

# %%
sns.relplot(x="Q8_2",y="mobile_money", hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q8_2",y="savings", hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q8_2",y="borrowing",hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q8_2",y="insurance",hue = 'mobile_money_classification',data=training,kind="line")

# %%
sns.relplot(x="Q8_3",y="mobile_money", hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q8_3",y="savings", hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q8_3",y="borrowing",hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q8_3",y="insurance",hue = 'mobile_money_classification',data=training,kind="line")

# %%
sns.relplot(x="Q8_4",y="mobile_money", hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q8_4",y="savings", hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q8_4",y="borrowing",hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q8_4",y="insurance",hue = 'mobile_money_classification',data=training,kind="line")

# %%
sns.relplot(x="Q8_5",y="mobile_money", hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q8_5",y="savings", hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q8_5",y="borrowing",hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q8_5",y="insurance",hue = 'mobile_money_classification',data=training,kind="line")

# %%
sns.relplot(x="Q8_6",y="mobile_money", hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q8_6",y="savings", hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q8_6",y="borrowing",hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q8_6",y="insurance",hue = 'mobile_money_classification',data=training,kind="line")

# %%
sns.relplot(x="Q8_7",y="mobile_money", hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q8_7",y="savings", hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q8_7",y="borrowing",hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q8_7",y="insurance",hue = 'mobile_money_classification',data=training,kind="line")

# %%
sns.relplot(x="Q8_8",y="mobile_money", hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q8_8",y="savings", hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q8_8",y="borrowing",hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q8_8",y="insurance",hue = 'mobile_money_classification',data=training,kind="line")

# %%
sns.relplot(x="Q8_9",y="mobile_money", hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q8_9",y="savings", hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q8_9",y="borrowing",hue = 'mobile_money_classification',data=training,kind="line")
sns.relplot(x="Q8_9",y="insurance",hue = 'mobile_money_classification',data=training,kind="line")

# %%
sns.catplot(x="Q1",y="mobile_money", hue = 'mobile_money_classification',data=training,kind="boxen")
sns.catplot(x="Q1",y="savings",hue = 'mobile_money_classification',data=training,kind="boxen")
sns.catplot(x="Q1",y="borrowing",hue = 'mobile_money_classification',data=training,kind="boxen")
sns.catplot(x="Q1",y="insurance",hue = 'mobile_money_classification',data=training,kind="boxen")

# %%
sns.catplot(x="Q2",y="mobile_money", hue = 'mobile_money_classification',data=training,kind="box")
sns.catplot(x="Q2",y="savings",hue = 'mobile_money_classification',data=training,kind="box")
sns.catplot(x="Q2",y="borrowing",hue = 'mobile_money_classification',data=training,kind="box")
sns.catplot(x="Q2",y="insurance",hue = 'mobile_money_classification',data=training,kind="box")

# %%
sns.catplot(x="Q3",y="mobile_money", hue = 'mobile_money_classification',data=training,kind="box")
sns.catplot(x="Q3",y="savings",hue = 'mobile_money_classification',data=training,kind="box")
sns.catplot(x="Q3",y="borrowing",hue = 'mobile_money_classification',data=training,kind="box")
sns.catplot(x="Q3",y="insurance",hue = 'mobile_money_classification',data=training,kind="box")

# %%
sns.catplot(x="Q6",y="mobile_money", hue = 'mobile_money_classification',data=training,kind="box")
sns.catplot(x="Q6",y="savings",hue = 'mobile_money_classification',data=training,kind="box")
sns.catplot(x="Q6",y="borrowing",hue = 'mobile_money_classification',data=training,kind="box")
sns.catplot(x="Q6",y="insurance",hue = 'mobile_money_classification',data=training,kind="box")

# %%
sns.catplot(x="Q8_1",y="mobile_money", hue = 'mobile_money_classification',data=training,kind="box")
sns.catplot(x="Q8_1",y="savings",hue = 'mobile_money_classification',data=training,kind="box")
sns.catplot(x="Q8_1",y="borrowing",hue = 'mobile_money_classification',data=training,kind="box")
sns.catplot(x="Q8_1",y="insurance",hue = 'mobile_money_classification',data=training,kind="box")

# %%
sns.catplot(x="Q8_2",y="mobile_money", hue = 'mobile_money_classification',data=training,kind="box")
sns.catplot(x="Q8_2",y="savings",hue = 'mobile_money_classification',data=training,kind="box")
sns.catplot(x="Q8_2",y="borrowing",hue = 'mobile_money_classification',data=training,kind="box")
sns.catplot(x="Q8_2",y="insurance",hue = 'mobile_money_classification',data=training,kind="box")

# %%
sns.catplot(x="Q8_3",y="mobile_money", hue = 'mobile_money_classification',data=training,kind="box")
sns.catplot(x="Q8_3",y="savings",hue = 'mobile_money_classification',data=training,kind="box")
sns.catplot(x="Q8_3",y="borrowing",hue = 'mobile_money_classification',data=training,kind="box")
sns.catplot(x="Q8_3",y="insurance",hue = 'mobile_money_classification',data=training,kind="box")

# %%
sns.catplot(x="Q8_4",y="mobile_money", hue = 'mobile_money_classification',data=training,kind="box")
sns.catplot(x="Q8_4",y="savings",hue = 'mobile_money_classification',data=training,kind="box")
sns.catplot(x="Q8_4",y="borrowing",hue = 'mobile_money_classification',data=training,kind="box")
sns.catplot(x="Q8_4",y="insurance",hue = 'mobile_money_classification',data=training,kind="box")

# %%
sns.catplot(x="Q8_5",y="mobile_money", hue = 'mobile_money_classification',data=training,kind="box")
sns.catplot(x="Q8_5",y="savings",hue = 'mobile_money_classification',data=training,kind="box")
sns.catplot(x="Q8_5",y="borrowing",hue = 'mobile_money_classification',data=training,kind="box")
sns.catplot(x="Q8_5",y="insurance",hue = 'mobile_money_classification',data=training,kind="box")

# %%
sns.catplot(x="Q8_6",y="mobile_money", hue = 'mobile_money_classification',data=training,kind="box")
sns.catplot(x="Q8_6",y="savings",hue = 'mobile_money_classification',data=training,kind="box")
sns.catplot(x="Q8_6",y="borrowing",hue = 'mobile_money_classification',data=training,kind="box")
sns.catplot(x="Q8_6",y="insurance",hue = 'mobile_money_classification',data=training,kind="box")

# %%
sns.catplot(x="Q8_7",y="mobile_money", hue = 'mobile_money_classification',data=training,kind="box")
sns.catplot(x="Q8_7",y="savings",hue = 'mobile_money_classification',data=training,kind="box")
sns.catplot(x="Q8_7",y="borrowing",hue = 'mobile_money_classification',data=training,kind="box")
sns.catplot(x="Q8_7",y="insurance",hue = 'mobile_money_classification',data=training,kind="box")

# %%
sns.catplot(x="Q8_8",y="mobile_money", hue = 'mobile_money_classification',data=training,kind="box")
sns.catplot(x="Q8_8",y="savings",hue = 'mobile_money_classification',data=training,kind="box")
sns.catplot(x="Q8_8",y="borrowing",hue = 'mobile_money_classification',data=training,kind="box")
sns.catplot(x="Q8_8",y="insurance",hue = 'mobile_money_classification',data=training,kind="box")

# %%
sns.catplot(x="Q8_9",y="mobile_money", hue = 'mobile_money_classification',data=training,kind="box")
sns.catplot(x="Q8_9",y="savings",hue = 'mobile_money_classification',data=training,kind="box")
sns.catplot(x="Q8_9",y="borrowing",hue = 'mobile_money_classification',data=training,kind="box")
sns.catplot(x="Q8_9",y="insurance",hue = 'mobile_money_classification',data=training,kind="box")

# %%
from scipy import stats
training=np.random.normal(loc=5,size=100,scale=2)
sns.distplot(training)

# %%
training = pd.read_csv("training.csv");
training_plot = sns.FacetGrid(training,col="mobile_money")
training_plot.map(plt.hist,"Q1")

# %%
training = pd.read_csv("training.csv");
training_plot = sns.FacetGrid(training,col="mobile_money")
training_plot.map(plt.hist,"Q2")

# %%
training_plot = sns.FacetGrid(training,col="mobile_money")
training_plot.map(plt.hist,"Q3")

# %% [markdown]
# The following graphs(scatter,line,box) are used to visually represent the relationship between financial services accessed (non, momible, both) and age, gender, marital status, land ownership and type of income.
